# %% [markdown]
# # Brief review of images, color, sampling, quantization, windowing
# Joshua Stough, DIP 365
#
# Through [Gonzalez/Woods](http://www.imageprocessingplace.com/index.htm) 2.4
#
# During this module we learned about the following concepts.
#
# - Color: a combination of red green and blue
# - Digital Images: a collection of pixels
#     - Pixel: picture element, some spatial extent with color
# - Histograms: graph that shows the relative distribution of values
# - Resolution as a loaded word, could refer to:
#     - Sampling: number of pixels hight by width
#     - Resolution: pixels per spacial unit, pixel density, dpi-dots per inch
#     - Quantization, Color Depth: number of possible color values; bit depth
# - Contrast: the realtive difference between two colors ...
# - Windowing

# %% [markdown]
# ### Import statements
# Useful to have these at top. And if you figure out you need an additional one, put it in here and restart the kernel.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import rescale

# %% [markdown]
# ## Color

# %%
I = np.zeros((100,100, 3))

plt.imshow(I)

# like https://en.wikibooks.org/wiki/Python_Imaging_Library/Editing_Pixels
# but without the silly double for loop

X, Y = np.meshgrid(range(0,100), range(0,100), indexing='ij')

I = np.stack([(255/99)*X, (255/99)*Y, 100*np.ones((100,100))], axis=2)

#I = I/I.max()
plt.imshow(I.astype('uint8'))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Histograms

# %% [markdown]
# ### Resolution

# %%
I = plt.imread('grandCanyon.jpg')


# Scale the image down
sI = rescale(I, (1/32),
             order=1,
             anti_aliasing=True,
             multichannel=True)

# rescale
reI = rescale(sI, 32,
              order=0,
              anti_aliasing=False,
              multichannel=True)

f, ax = plt.subplots(1,2, sharex=True, sharey=True,
                     figsize=(12, 3))

ax[0].imshow(I, interpolation=None)
ax[0].set_title('Original')

ax[1].imshow(reI, interpolation=None)
ax[1].set_title('Quarter Res')

# [a.axes.get_xaxis().set_visible(False) for a in ax]
# [a.axes.get_yaxis().set_visible(False) for a in ax]
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8ab8711314ae> in <module>
# ----> 1 I = plt.imread('grandCanyon.jpg')
#       2
#       3
#       4 # Scale the image down
#       5 sI = rescale(I, (1/32),
#
# /usr/remote/anaconda-3.7-2020-01-14/lib/python3.7/site-packages/matplotlib/pyplot.py in imread(fname, format)
#    2133 @docstring.copy(matplotlib.image.imread)
#    2134 def imread(fname, format=None):
# -> 2135     return matplotlib.image.imread(fname, format)
#    2136
#    2137
#
# /usr/remote/anaconda-3.7-2020-01-14/lib/python3.7/site-packages/matplotlib/image.py in imread(fname, format)
#    1415                              'with Pillow installed matplotlib can handle '
#    1416                              'more images' % list(handlers))
# -> 1417         with Image.open(fname) as image:
#    1418             return pil_to_array(image)
#    1419
#
# /usr/remote/anaconda-3.7-2020-01-14/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'grandCanyon.jpg'

# %% [markdown]
# ### Windowing
